# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("laptop_data.csv")
data.sample(5)
# Out:
#      Unnamed: 0 Company            TypeName  Inches      ScreenResolution  \
# 231         231      HP            Notebook    15.6              1366x768
# 57           57    Asus            Notebook    15.6              1366x768
# 590         590    Asus  2 in 1 Convertible    15.6  Touchscreen 1366x768
# 700         700    Dell              Gaming    15.6     Full HD 1920x1080
# 989         989    Dell            Notebook    14.0     Full HD 1920x1080
#
#                              Cpu  Ram     Memory                      Gpu  \
# 231    AMD E-Series 9000e 1.5GHz  4GB  500GB HDD            AMD Radeon R2
# 57    Intel Core i5 7200U 2.5GHz  4GB  256GB SSD    Intel HD Graphics 620
# 590   Intel Core i5 7200U 2.5GHz  8GB    1TB HDD    Intel HD Graphics 520
# 700  Intel Core i5 7300HQ 2.5GHz  8GB    1TB HDD  Nvidia GeForce GTX 1050
# 989   Intel Core i5 7200U 2.5GHz  8GB  128GB SSD   Intel HD Graphics 620
#
#           OpSys  Weight       Price
# 231  Windows 10   2.1kg  17582.4000
# ...

# %%
data.drop('Unnamed: 0' , axis =1 , inplace = True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
data.shape
# Out:
# (1303, 11)

# %%
data.isna().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 29

# %%
data.drop_duplicates()
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
(data.Company.value_counts())
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
def company(x):
    if (data.Company.value_counts())[x] > 10:
        return x
    else:
        return "Other"
    
data['Company'] = data['Company'].apply(company)

# %%
data.sample(5)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 431   Lenovo   Notebook    13.3  IPS Panel Full HD 1920x1080
# 102     Dell   Notebook    15.6            Full HD 1920x1080
# 98      Asus   Notebook    15.6            Full HD 1920x1080
# 406  Toshiba  Ultrabook    13.3            Full HD 1920x1080
# 543     Acer     Gaming    15.6            Full HD 1920x1080
#
#                              Cpu   Ram     Memory                      Gpu  \
# 431   Intel Core i7 7500U 2.7GHz   8GB  256GB SSD    Intel HD Graphics 620
# 102   Intel Core i5 8250U 1.6GHz   8GB    1TB HDD           AMD Radeon 520
# 98    Intel Core i3 7100U 2.4GHz   6GB  256GB SSD      Nvidia GeForce 920M
# 406   Intel Core i7 6500U 2.5GHz  16GB  512GB SSD    Intel HD Graphics 520
# 543  Intel Core i5 7300HQ 2.5GHz   8GB    1TB HDD  Nvidia GeForce GTX 1050
#
#           OpSys Weight     Price
# 431  Windows 10  1.4kg  53812.80
# 102       Linux  2.2kg  34472.16
# 98   Windows 10    2kg  30742.56
# ...

# %%
data.TypeName.value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
def typename(x):
    if (data.TypeName.value_counts())[x] > 30:
        return x
    else:
        return "Other"
    
data['TypeName'] = data['TypeName'].apply(typename)

# %%
data.sample(5)
# Out:
#       Company            TypeName  Inches                 ScreenResolution  \
# 655   Toshiba            Notebook    15.6      IPS Panel Full HD 1920x1080
# 434    Lenovo            Notebook    15.6                Full HD 1920x1080
# 158      Dell  2 in 1 Convertible    15.6  Full HD / Touchscreen 1920x1080
# 1129       HP              Gaming    17.3      IPS Panel Full HD 1920x1080
# 297      Dell               Other    17.3                Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 655    Intel Core i5 7200U 2.5GHz   8GB             500GB HDD
# 434   Intel Core i7 7820HQ 2.9GHz  16GB             512GB SSD
# 158    Intel Core i7 8550U 1.8GHz   8GB             256GB SSD
# 1129  Intel Core i5 6300HQ 2.3GHz   8GB  128GB SSD +  1TB HDD
# 297   Intel Core i7 7820HQ 2.9GHz  16GB             256GB SSD
#
#                           Gpu       OpSys  Weight        Price
# 655     Intel HD Graphics 620  Windows 10   2.0kg   56689.9200
# ...

# %%
data['Y res'] = data.ScreenResolution.str.split("x" , expand = True)[1]

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
data['X res'] = data.ScreenResolution.str.split("x" , expand = True)[0].str.split(" ").apply(lambda x: x[-1])

# %%
data.sample(5)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 1157  Lenovo  Ultrabook    14.0            Full HD 1920x1080
# 132     Acer  Ultrabook    14.0  IPS Panel Full HD 1920x1080
# 1145      HP      Other    15.6            Full HD 1920x1080
# 481     Dell   Notebook    15.6                     1366x768
# 490   Lenovo   Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                               Cpu   Ram     Memory                     Gpu  \
# 1157   Intel Core i7 6600U 2.6GHz  12GB  512GB SSD   Intel HD Graphics 520
# 132    Intel Core i7 8550U 1.8GHz   8GB  256GB SSD  Intel UHD Graphics 620
# 1145  Intel Core i7 6700HQ 2.6GHz   8GB  256GB SSD    Nvidia Quadro M1000M
# 481    Intel Core i3 7100U 2.4GHz   4GB    1TB HDD   Intel HD Graphics 620
# 490    Intel Core i5 7200U 2.5GHz   8GB  256GB SSD    Nvidia GeForce 940MX
#
#            OpSys  Weight        Price Y res X res
# 1157   Windows 7   1.4kg  122490.7200  1080  1920
# ...

# %%
data.drop("ScreenResolution" , axis = 1 , inplace = True)

# %%
data.sample(5)
# Out:
#      Company            TypeName  Inches                          Cpu   Ram  \
# 1232    Dell            Notebook    15.6   Intel Core i3 7100U 2.4GHz   8GB
# 65      Asus           Ultrabook    15.6  Intel Core i7 7700HQ 2.8GHz  16GB
# 628     Asus  2 in 1 Convertible    13.3   Intel Core i5 7200U 2.5GHz   6GB
# 1196  Lenovo            Notebook    15.6     Intel Core i3 6006U 2GHz   4GB
# 556    Other            Notebook    13.3  Intel Atom x5-Z8350 1.44GHz   4GB
#
#                   Memory                         Gpu       OpSys  Weight  \
# 1232             1TB HDD       Intel HD Graphics 620  Windows 10   2.3kg
# 65             512GB SSD  Nvidia GeForce GTX 1050 Ti  Windows 10   1.8kg
# 628              1TB HDD       Intel HD Graphics 620  Windows 10   1.5kg
# 1196             1TB HDD          AMD Radeon R5 M430       No OS   1.9kg
# 556   32GB Flash Storage           Intel HD Graphics  Windows 10  1.35kg
#
#             Price Y res X res
# 1232   24988.8528   768  1366
# ...

# %%
data.Cpu.value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
data.Cpu.unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
def cpu(x):
    if 'Intel Core i5' in x or 'Intel Core i3' in x or "Intel Core i7" in x:
        return x[0:13]
    elif "Intel" in x:
        return "Other Intel Processor"
    elif "AMD" in x:
        return "AMD"
    else:
        return "Other"

# %%
data['Cpu'] = data.Cpu.apply(cpu)

# %%
data.sample(5)
# Out:
#      Company  TypeName  Inches                    Cpu  Ram  \
# 664      MSI    Gaming    17.3          Intel Core i7  8GB
# 254     Acer  Notebook    17.3          Intel Core i3  4GB
# 400   Lenovo  Notebook    15.6  Other Intel Processor  4GB
# 1026      HP  Notebook    14.0          Intel Core i5  4GB
# 803     Dell  Notebook    15.6          Intel Core i5  8GB
#
#                     Memory                      Gpu       OpSys  Weight  \
# 664   128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10   2.7kg
# 254              256GB SSD     Nvidia GeForce MX130  Windows 10     3kg
# 400                1TB HDD    Intel HD Graphics 500  Windows 10   2.2kg
# 1026             500GB HDD    Intel HD Graphics 620  Windows 10  2.31kg
# 803              256GB SSD  Nvidia GeForce GTX 1050  Windows 10  2.06kg
#
#            Price Y res X res
# 664   79215.1056  1080  1920
# 254   37402.5600  1080  1920
# 400   16303.6800   768  1366
# 1026  63349.9200   768  1366
# ...

# %%
data.Cpu.unique()
# Out:
# array(['Intel Core i5', 'Intel Core i7', 'AMD', 'Intel Core i3',
#        'Other Intel Processor', 'Other'], dtype=object)

# %%
data['Ram'] = data.Ram.str.replace("GB","").astype('int')

# %%
data.sample(5)
# Out:
#     Company            TypeName  Inches                    Cpu  Ram  \
# 310  Lenovo            Notebook    13.3          Intel Core i5    8
# 389  Lenovo  2 in 1 Convertible    14.0          Intel Core i7   16
# 942    Acer            Notebook    15.6          Intel Core i5    4
# 876    Asus            Notebook    15.6  Other Intel Processor    4
# 335      HP            Notebook    14.0          Intel Core i5    8
#
#         Memory                    Gpu       OpSys  Weight        Price Y res  \
# 310  256GB SSD  Intel HD Graphics 620  Windows 10   1.1kg   53226.7200  1080
# 389  512GB SSD  Intel HD Graphics 620  Windows 10  1.42kg  133679.5200  1440
# 942  500GB HDD  Intel HD Graphics 620  Windows 10  2.23kg   32980.3200   768
# 876    1TB HDD  Intel HD Graphics 505       Linux     2kg   21258.1872   768
# 335  256GB SSD  Intel HD Graphics 620  Windows 10  1.48kg   67559.0400  1080
#
#     X res
# 310  1920
# 389  2560
# 942  1366
# 876  1366
# 335  1920

# %%
data.Memory.unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
# Think so there is dirty data like what is : 256GB SSD + 256GB SSD  he he he

# %%
# Assuming that first there is SSD and then HDD

# %%
def ssd(x):
    if "SSD" in x and "+" not in x:
        return x.split(" ")[0].replace("TB" , "000GB").replace("GB","")
    elif "+" in x and "SSD" in x:
        a = x.split("+")
        if "SSD" in a[0]:
            return a[0].split(" ")[0].replace("TB" , "000GB").replace("GB","")
        elif  "SSD" in a[1]:
            return a[1].split(" ")[2].replace("TB" , "000GB").replace("GB","")
    else:
        return 0
def hdd(x):
    if "HDD" in x and "+" not in x:
        return x.split(" ")[0].replace("TB" , "000GB").replace("GB","")
    elif "+" in x and "HDD" in x:
        a = x.split("+")
        if "HDD" in a[0]:
            return a[0].split(" ")[0].replace("TB" , "000GB").replace("GB","")
        elif  "HDD" in a[1]:
            return a[1].split(" ")[2].replace("TB" , "000GB").replace("GB","")
    else:
        return 0
def hybrid(x):
    if "Hybrid" in x and "+" not in x:
        return x.split(" ")[0].replace("TB" , "000GB").replace("GB","")
    elif "+" in x and "Hybrid" in x:
        a = x.split("+")
        if "Hybrid" in a[0]:
            return a[0].split(" ")[0].replace("TB" , "000GB").replace("GB","")
        elif  "Hybrid" in a[1]:
            return a[1].split(" ")[2].replace("TB" , "000GB").replace("GB","")
    else:
        return 0
def flash(x):
    if "Flash Storage" in x and "+" not in x:
        return x.split(" ")[0].replace("TB" , "000GB").replace("GB","")
    elif "+" in x and "Flash Storage" in x:
        a = x.split("+")
        if "Flash Storage" in a[0]:
            return a[0].split(" ")[0].replace("TB" , "000GB").replace("GB","")
        elif  "Flash Storage" in a[1]:
            return a[1].split(" ")[2].replace("TB" , "000GB").replace("GB","")
    else:
        return 0

# %%
data['SSD'] = data.Memory.apply(ssd)
data['HDD'] = data.Memory.apply(hdd)
data['Hybrid'] = data.Memory.apply(hybrid)
data['Flash'] = data.Memory.apply(flash)

# %%
data.sample(5)
# Out:
#     Company   TypeName  Inches                    Cpu  Ram  \
# 613    Dell   Notebook    15.6          Intel Core i3    4
# 584    Dell      Other    11.6  Other Intel Processor    4
# 200    Dell     Gaming    15.6          Intel Core i7   16
# 767    Dell     Gaming    15.6          Intel Core i7   16
# 720  Lenovo  Ultrabook    14.0          Intel Core i7    8
#
#                    Memory                      Gpu       OpSys  Weight  \
# 613               1TB HDD    Intel HD Graphics 520       Linux  2.25kg
# 584    16GB Flash Storage    Intel HD Graphics 400   Chrome OS  1.26kg
# 200  512GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10  2.65kg
# 767  128GB SSD +  1TB HDD  Nvidia GeForce GTX 960M  Windows 10  2.72kg
# 720             512GB SSD    Intel HD Graphics 520  Windows 10  1.17kg
#
#           Price Y res X res  SSD   HDD Hybrid Flash
# 613  19127.5200   768  1366    0  1000      0     0
# 584  15717.6000   768  1366    0     0      0    16
# ...

# %%
data.Gpu.unique()
# Out:
# array(['Intel Iris Plus Graphics 640', 'Intel HD Graphics 6000',
#        'Intel HD Graphics 620', 'AMD Radeon Pro 455',
#        'Intel Iris Plus Graphics 650', 'AMD Radeon R5',
#        'Intel Iris Pro Graphics', 'Nvidia GeForce MX150',
#        'Intel UHD Graphics 620', 'Intel HD Graphics 520',
#        'AMD Radeon Pro 555', 'AMD Radeon R5 M430',
#        'Intel HD Graphics 615', 'AMD Radeon Pro 560',
#        'Nvidia GeForce 940MX', 'Intel HD Graphics 400',
#        'Nvidia GeForce GTX 1050', 'AMD Radeon R2', 'AMD Radeon 530',
#        'Nvidia GeForce 930MX', 'Intel HD Graphics',
#        'Intel HD Graphics 500', 'Nvidia GeForce 930MX ',
#        'Nvidia GeForce GTX 1060', 'Nvidia GeForce 150MX',
#        'Intel Iris Graphics 540', 'AMD Radeon RX 580',
#        'Nvidia GeForce 920MX', 'AMD Radeon R4 Graphics', 'AMD Radeon 520',
#        'Nvidia GeForce GTX 1070', 'Nvidia GeForce GTX 1050 Ti',
#        'Nvidia GeForce MX130', 'AMD R4 Graphics',
# ...

# %%
def graphics(x):
    return x.split(" ")[0]

# %%
data['GPU'] = data.Gpu.apply(graphics)

# %%
data.GPU.value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: GPU, dtype: int64

# %%
data = data[data['GPU'] != "ARM"]

# %%
data.GPU.value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: GPU, dtype: int64

# %%
data.sample(5)
# Out:
#      Company   TypeName  Inches            Cpu  Ram               Memory  \
# 1152  Lenovo   Notebook    15.6  Intel Core i5    8              1TB HDD
# 6      Apple  Ultrabook    15.4  Intel Core i7   16  256GB Flash Storage
# 714     Dell   Notebook    15.6  Intel Core i5   16            512GB SSD
# 809   Lenovo   Notebook    15.6  Intel Core i5    4              1TB HDD
# 778    Other     Gaming    14.0  Intel Core i7   16            512GB SSD
#
#                           Gpu       OpSys  Weight        Price Y res X res  \
# 1152       AMD Radeon R5 M330       No OS  2.32kg   31914.7200  1080  1920
# 6     Intel Iris Pro Graphics    Mac OS X  2.04kg  114017.6016  1800  2880
# 714     Intel HD Graphics 620  Windows 10  1.93kg   76012.4448  1080  1920
# 809       Nvidia GeForce 920M  Windows 10   2.4kg   32447.5200  1080  1920
# 778   Nvidia GeForce GTX 1060  Windows 10  1.95kg  154458.7200  1080  1920
#
#       SSD   HDD Hybrid Flash     GPU
# 1152    0  1000      0     0     AMD
# ...

# %%
data.drop(['Memory' , 'Gpu'] , axis = 1 , inplace = True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2036\1568804194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['Memory' , 'Gpu'] , axis = 1 , inplace = True)

# %%
data
# Out:
#      Company            TypeName  Inches                    Cpu  Ram  \
# 0      Apple           Ultrabook    13.3          Intel Core i5    8
# 1      Apple           Ultrabook    13.3          Intel Core i5    8
# 2         HP            Notebook    15.6          Intel Core i5    8
# 3      Apple           Ultrabook    15.4          Intel Core i7   16
# 4      Apple           Ultrabook    13.3          Intel Core i5    8
# ...      ...                 ...     ...                    ...  ...
# 1298  Lenovo  2 in 1 Convertible    14.0          Intel Core i7    4
# 1299  Lenovo  2 in 1 Convertible    13.3          Intel Core i7   16
# 1300  Lenovo            Notebook    14.0  Other Intel Processor    2
# 1301      HP            Notebook    15.6          Intel Core i7    6
# 1302    Asus            Notebook    15.6  Other Intel Processor    4
#
#            OpSys  Weight        Price Y res X res  SSD   HDD Hybrid Flash  \
# ...

# %%
data.OpSys.unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux', 'Android',
#        'Windows 10 S', 'Chrome OS', 'Windows 7'], dtype=object)

# %%
def os(x):
    if "Windows" in x :
        return "Windows" 
    elif "Linux" in x:
            return "Linux"
    elif x == "Android" or x==  "Chrome OS" or x== "No OS":
        return "Other"
    elif x == "macOS" or x == "Mac OS X":
        return "Mac"
data['OpSys'] = data.OpSys.apply(os)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2036\2127753008.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['OpSys'] = data.OpSys.apply(os)

# %%
data.sample(10)
# Out:
#       Company            TypeName  Inches                    Cpu  Ram  \
# 253    Lenovo  2 in 1 Convertible    13.9          Intel Core i7    8
# 752      Asus            Notebook    15.6          Intel Core i5    4
# 1118  Toshiba           Ultrabook    13.3          Intel Core i7   16
# 1245     Asus              Gaming    15.6          Intel Core i7   16
# 335        HP            Notebook    14.0          Intel Core i5    8
# 808      Dell              Gaming    15.6          Intel Core i7   16
# 1104   Lenovo              Gaming    15.6          Intel Core i7   16
# 961    Lenovo           Ultrabook    12.5          Intel Core i5    8
# 609      Acer            Notebook    14.0  Other Intel Processor    4
# 284      Acer            Notebook    15.6          Intel Core i7    8
#
#         OpSys  Weight      Price Y res X res  SSD   HDD Hybrid Flash     GPU
# 253   Windows  1.37kg   98514.72  1080  1920  512     0      0     0   Intel
# ...

# %%
data.Weight = data.Weight.str.replace("kg" , "")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2036\64395553.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Weight = data.Weight.str.replace("kg" , "")

# %%
data.sample(5)
# Out:
#      Company            TypeName  Inches            Cpu  Ram    OpSys Weight  \
# 1032     MSI              Gaming    17.3  Intel Core i7    8  Windows    2.7
# 924   Lenovo  2 in 1 Convertible    13.3  Intel Core i5    8  Windows   1.37
# 852     Dell            Notebook    17.3  Intel Core i7    8    Linux   2.83
# 316       HP  2 in 1 Convertible    13.3  Intel Core i7   16  Windows   1.29
# 1206      HP            Notebook    15.6  Intel Core i5    8  Windows   1.91
#
#            Price Y res X res   SSD   HDD Hybrid Flash     GPU
# 1032   63499.104  1080  1920   128  1000      0     0  Nvidia
# 924    97236.000  1080  1920   512     0      0     0   Intel
# 852    46087.200  1080  1920     0  1000      0     0     AMD
# 316   130482.720  2160  3840  1000     0      0     0   Intel
# 1206   30849.120   768  1366   256     0      0     0   Intel

# %%
data.isna().sum()
# Out:
# Company       0
# TypeName      0
# Inches        0
# Cpu           0
# Ram           0
# OpSys       115
# Weight        0
# Price         0
# Y res         0
# X res         0
# SSD           0
# HDD           0
# Hybrid        0
# Flash         0
# GPU           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 30

# %%
data.drop_duplicates()
# Out:
#      Company            TypeName  Inches                    Cpu  Ram    OpSys  \
# 0      Apple           Ultrabook    13.3          Intel Core i5    8     None
# 1      Apple           Ultrabook    13.3          Intel Core i5    8     None
# 2         HP            Notebook    15.6          Intel Core i5    8     None
# 3      Apple           Ultrabook    15.4          Intel Core i7   16     None
# 4      Apple           Ultrabook    13.3          Intel Core i5    8     None
# ...      ...                 ...     ...                    ...  ...      ...
# 1269    Asus            Notebook    15.6          Intel Core i7    4  Windows
# 1270  Lenovo  2 in 1 Convertible    14.0          Intel Core i7    4  Windows
# 1271  Lenovo  2 in 1 Convertible    13.3          Intel Core i7   16  Windows
# 1272  Lenovo            Notebook    14.0  Other Intel Processor    2  Windows
# 1273      HP            Notebook    15.6          Intel Core i7    6  Windows
#
# ...

# %%
data.dtypes
# Out:
# Company      object
# TypeName     object
# Inches      float64
# Cpu          object
# Ram           int32
# OpSys        object
# Weight       object
# Price       float64
# Y res        object
# X res        object
# SSD          object
# HDD          object
# Hybrid       object
# Flash        object
# GPU          object
# dtype: object

# %%
data[['Weight' , "X res" , "Y res" , "SSD" , "HDD" , "Flash" , "Hybrid"]] = data[['Weight' , "X res" , "Y res" , "SSD" , "HDD" , "Flash" , "Hybrid"]].astype("float")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2036\2097206771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['Weight' , "X res" , "Y res" , "SSD" , "HDD" , "Flash" , "Hybrid"]] = data[['Weight' , "X res" , "Y res" , "SSD" , "HDD" , "Flash" , "Hybrid"]].astype("float")

# %%
data['ppi'] = ((data['X res'])**2 + (data['Y res'])**2)**0.5 / data['Inches']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2036\3611765766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ppi'] = ((data['X res'])**2 + (data['Y res'])**2)**0.5 / data['Inches']

# %%
data.corr()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2036\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#           Inches       Ram    Weight     Price     Y res     X res       SSD  \
# Inches  1.000000  0.237129  0.827397  0.067329 -0.092934 -0.069875 -0.110636
# Ram     0.237129  1.000000  0.383362  0.742905  0.426357  0.434095  0.604088
# Weight  0.827397  0.383362  1.000000  0.209867 -0.052041 -0.031866 -0.063507
# Price   0.067329  0.742905  0.209867  1.000000  0.554591  0.557369  0.676066
# Y res  -0.092934  0.426357 -0.052041  0.554591  1.000000  0.994480  0.526886
# X res  -0.069875  0.434095 -0.031866  0.557369  0.994480  1.000000  0.534516
# SSD    -0.110636  0.604088 -0.063507  0.676066  0.526886  0.534516  1.000000
# ...

# %%
data.drop(['Flash' , 'Hybrid' , "Inches" , "X res" , "Y res"] , axis =1 , inplace = True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2036\4162786418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['Flash' , 'Hybrid' , "Inches" , "X res" , "Y res"] , axis =1 , inplace = True)

# %%
# Let's do some data visualization

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
data
# Out:
#      Company            TypeName                    Cpu  Ram    OpSys  Weight  \
# 0      Apple           Ultrabook          Intel Core i5    8     None    1.37
# 1      Apple           Ultrabook          Intel Core i5    8     None    1.34
# 2         HP            Notebook          Intel Core i5    8     None    1.86
# 3      Apple           Ultrabook          Intel Core i7   16     None    1.83
# 4      Apple           Ultrabook          Intel Core i5    8     None    1.37
# ...      ...                 ...                    ...  ...      ...     ...
# 1298  Lenovo  2 in 1 Convertible          Intel Core i7    4  Windows    1.80
# 1299  Lenovo  2 in 1 Convertible          Intel Core i7   16  Windows    1.30
# 1300  Lenovo            Notebook  Other Intel Processor    2  Windows    1.50
# 1301      HP            Notebook          Intel Core i7    6  Windows    2.19
# 1302    Asus            Notebook  Other Intel Processor    4  Windows    2.20
#
# ...

# %%
sns.distplot(np.log(data.Price))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2036\1321026054.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(data.Price))
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
data['Company'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
data.groupby(by = data.Company)['Price'].mean().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Company'>

# %%
data.groupby(by = data.Company)['Weight'].mean().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Company'>

# %%
data.groupby(by = data.Company)['ppi'].mean().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Company'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder , StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression , Ridge 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor , VotingRegressor , GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score

# %%
x = data.drop('Price' , axis =1 )
y = np.log(data.Price)

# %%
x
# Out:
#      Company            TypeName                    Cpu  Ram    OpSys  Weight  \
# 0      Apple           Ultrabook          Intel Core i5    8     None    1.37
# 1      Apple           Ultrabook          Intel Core i5    8     None    1.34
# 2         HP            Notebook          Intel Core i5    8     None    1.86
# 3      Apple           Ultrabook          Intel Core i7   16     None    1.83
# 4      Apple           Ultrabook          Intel Core i5    8     None    1.37
# ...      ...                 ...                    ...  ...      ...     ...
# 1298  Lenovo  2 in 1 Convertible          Intel Core i7    4  Windows    1.80
# 1299  Lenovo  2 in 1 Convertible          Intel Core i7   16  Windows    1.30
# 1300  Lenovo            Notebook  Other Intel Processor    2  Windows    1.50
# 1301      HP            Notebook          Intel Core i7    6  Windows    2.19
# 1302    Asus            Notebook  Other Intel Processor    4  Windows    2.20
#
# ...

# %%
xtrain , xtest , ytrain , ytest = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
xtrain
# Out:
#      Company            TypeName                    Cpu  Ram    OpSys  Weight  \
# 147     Asus            Notebook  Other Intel Processor    4  Windows    2.00
# 342       HP            Notebook          Intel Core i3    8  Windows    2.10
# 1003      HP            Notebook          Intel Core i5    4  Windows    1.64
# 814     Dell            Notebook          Intel Core i5    8  Windows    2.18
# 344     Dell           Ultrabook          Intel Core i7    8  Windows    1.20
# ...      ...                 ...                    ...  ...      ...     ...
# 1095    Acer            Notebook          Intel Core i5    8  Windows    2.40
# 1130      HP            Notebook          Intel Core i7    8  Windows    2.04
# 1295    Dell            Notebook          Intel Core i7    8    Linux    2.30
# 860   Lenovo            Notebook          Intel Core i5    8  Windows    2.30
# 1126  Lenovo  2 in 1 Convertible  Other Intel Processor    4  Windows    0.69
#
# ...

# %%
xtest
# Out:
#      Company  TypeName                    Cpu  Ram    OpSys  Weight    SSD  \
# 478     Dell  Notebook          Intel Core i5    8  Windows    2.20    0.0
# 724      MSI    Gaming          Intel Core i7    8  Windows    2.70  128.0
# 312      MSI    Gaming          Intel Core i7   16  Windows    2.80  256.0
# 851     Asus    Gaming          Intel Core i7   16  Windows    2.10  128.0
# 1276    Dell  Notebook          Intel Core i3    6  Windows    2.30    0.0
# ...      ...       ...                    ...  ...      ...     ...    ...
# 199       HP  Notebook          Intel Core i7    8  Windows    2.50  256.0
# 296     Acer  Notebook          Intel Core i7    8    Linux    2.50  256.0
# 286   Lenovo  Notebook          Intel Core i7    8  Windows    1.95  256.0
# 997     Acer  Notebook  Other Intel Processor    4  Windows    2.40    0.0
# 10        HP  Notebook          Intel Core i5    4     None    1.86    0.0
#
#          HDD     GPU         ppi
# 478   1000.0     AMD  141.211998
# ...

# %%
ytest
# Out:
# 478     10.490274
# 724     11.182294
# 312     11.624777
# 851     11.524644
# 1276    10.104611
#           ...
# 199     10.927333
# 296     10.862093
# 286     10.975895
# 997      9.915732
# 10       9.951658
# Name: Price, Length: 261, dtype: float64

# %%
a = OneHotEncoder()
a.fit(x[['Company','TypeName','Cpu','OpSys','GPU']])
cate = a.categories_

# %%
col1 = ColumnTransformer(transformers=[('encode' , OneHotEncoder(drop = "first" , handle_unknown='ignore', categories=cate),
                                       [0,1,2,4,8])] , remainder = 'passthrough')

# %%
newtrain = col1.fit_transform(xtrain)
newtest = col1.transform(xtest)

# %%
col2 = ColumnTransformer(transformers=[('scale' , StandardScaler() , slice(0,30))])

# %%
newtrain = col2.fit_transform(newtrain)
newtest = col2.transform(newtest)

# %%
newtrain
# Out:
# array([[-0.13634881,  2.63563368, -0.53551265, ..., -1.00334252,
#          1.16440515, -0.13553807],
#        [-0.13634881, -0.3794154 , -0.53551265, ..., -1.00334252,
#          1.16440515, -0.13553807],
#        [-0.13634881, -0.3794154 , -0.53551265, ..., -1.00334252,
#          0.17786206, -0.82510396],
#        ...,
#        [-0.13634881, -0.3794154 ,  1.86736953, ..., -1.00334252,
#          1.16440515, -1.09550871],
#        [-0.13634881, -0.3794154 , -0.53551265, ..., -1.00334252,
#          1.16440515, -0.13553807],
#        [-0.13634881, -0.3794154 , -0.53551265, ..., -1.00334252,
#         -0.80868103,  1.81848851]])

# %%
lr = LinearRegression().fit(newtrain , ytrain)
ypred = lr.predict(newtest)
r2_score(ytest , ypred) ,np.mean(cross_val_score(lr , newtrain , ytrain))
# Out:
# (0.7980767613907624, 0.8026212380165243)

# %%
rid = Ridge()
np.mean(cross_val_score(rid , newtrain , ytrain))
# Out:
# 0.8026562344615377

# %%
rf = RandomForestRegressor().fit(newtrain , ytrain)
ypred = rf.predict(newtest)
r2_score(ytest , ypred) , np.mean(cross_val_score(rf , newtrain , ytrain))
# Out:
# (0.8745839159460678, 0.8666587256629924)

# %%
gd = GradientBoostingRegressor(n_estimators=500 ,  min_samples_split=5 , min_samples_leaf=2 ).fit(newtrain , ytrain)
ypred = gd.predict(newtest)
r2_score(ytest , ypred) , np.mean(cross_val_score(gd , newtrain , ytrain))
# Out:
# (0.879253351740474, 0.8890086834871305)

# %%
xg = XGBRegressor(n_estimators = 100).fit(newtrain , ytrain)
ypred = xg.predict(newtest)
r2_score(ytest , ypred) , np.mean(cross_val_score(xg , newtrain , ytrain))
# Out:
# (0.885616393480248, 0.8824170262826051)

# %%
lgb = LGBMRegressor()
np.mean(cross_val_score(lgb , newtrain , ytrain))
# Out:
# 0.8696867779642992

# %%
svr = SVR()
np.mean(cross_val_score(svr , newtrain , ytrain))
# Out:
# 0.8630949131847263

# %%
knn = KNeighborsRegressor(n_neighbors=5)
np.mean(cross_val_score(knn , newtrain , ytrain))
# Out:
# 0.8059616926896525

# %%
dt = DecisionTreeRegressor(min_samples_leaf=5,min_samples_split=10).fit(newtrain , ytrain)
ypred = dt.predict(newtest)
r2_score(ytest , ypred) , np.mean(cross_val_score(dt , newtrain , ytrain))
# Out:
# (0.8454871179445123, 0.8177205672395506)

# %%
vr = VotingRegressor(estimators = [ ('xg' , xg) , ('gd' , gd) , ('rf',rf)] , weights=[2,3,1])
np.mean(cross_val_score(vr , newtrain , ytrain))
# Out:
# 0.8935626516667158

# %%
col3 = vr

pipe = Pipeline([('1',col1),('2',col2),('3',col3)])
pipe
# Out:
# Pipeline(steps=[('1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('encode',
#                                                   OneHotEncoder(categories=[array(['Acer', 'Apple', 'Asus', 'Dell', 'HP', 'Lenovo', 'MSI', 'Other',
#        'Toshiba'], dtype=object),
#                                                                             array(['2 in 1 Convertible', 'Gaming', 'Notebook', 'Other', 'Ultrabook'],
#       dtype=object),
#                                                                             array(['AMD', 'Intel Core i3', 'Intel Core i5', 'Intel Core i7',
#        'Other Intel Pr...
#                                                            max_cat_to_onehot=None,
#                                                            max_delta_step=None,
#                                                            max_depth=None,
# ...

# %%
pipe.fit(xtrain , ytrain)
# Out:
# Pipeline(steps=[('1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('encode',
#                                                   OneHotEncoder(categories=[array(['Acer', 'Apple', 'Asus', 'Dell', 'HP', 'Lenovo', 'MSI', 'Other',
#        'Toshiba'], dtype=object),
#                                                                             array(['2 in 1 Convertible', 'Gaming', 'Notebook', 'Other', 'Ultrabook'],
#       dtype=object),
#                                                                             array(['AMD', 'Intel Core i3', 'Intel Core i5', 'Intel Core i7',
#        'Other Intel Pr...
#                                                            max_cat_to_onehot=None,
#                                                            max_delta_step=None,
#                                                            max_depth=None,
# ...

# %%
pipe.score(xtest , ytest)
# Out:
# 0.8913508985730545

# %%
import pickle
pickle.dump(pipe , open('laptop.pkl','wb'))

# %%
model = pickle.load(open('laptop.pkl','rb'))
model.predict(np.array([["Dell","Notebook","Intel Core i5",8,"Windows",2.20,0.0,1000.0,"AMD",141.211998]]))
# Out:
# C:\Python 310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([10.54441627])
